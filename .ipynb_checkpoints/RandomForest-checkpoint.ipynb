# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
training_data=pd.read_csv('Resources/train_cleaned.csv')
training_data.head()
# Out:
#        ID  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0  0x1608       19114.12            1824.843333                  3
# 1  0x160f       34847.84            3037.986667                  2
# 2  0x1612       34847.84            3037.986667                  2
# 3  0x1613       34847.84            3037.986667                  2
# 4  0x1615       34847.84            3037.986667                  2
#
#    Num_Credit_Card  Interest_Rate  Num_of_Loan  Delay_from_due_date  \
# 0                4              3            4                    3
# 1                4              6            1                    7
# 2                4              6            1                    3
# 3                4              6            1                    3
# 4                4              6            1                    3
#
#    Num_of_Delayed_Payment  Num_Credit_Inquiries Credit_Mix  Outstanding_Debt  \
# ...

# %%
testing_data=pd.read_csv('Resources/test_cleaned.csv')
testing_data.head()
# Out:
#        ID  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0  0x160a       19114.12            1824.843333                  3
# 1  0x160b       19114.12            1824.843333                  3
# 2  0x1623      143162.64           12187.220000                  1
# 3  0x162e       30689.89            2612.490833                  2
# 4  0x1630       30689.89            2612.490833                  2
#
#    Num_Credit_Card  Interest_Rate  Num_of_Loan  Delay_from_due_date  \
# 0                4              3            4                    3
# 1                4              3            4                    3
# 2                5              8            3                    6
# 3                5              4            1                    5
# 4                5              4            1                    5
#
#    Num_of_Delayed_Payment  Num_Credit_Inquiries Credit_Mix  Outstanding_Debt  \
# ...

# %%
X_train = training_data.drop(columns=['ID', 'Credit_Score', 'Credit_Mix', 'Payment_of_Min_Amount'])
y_train = training_data[['Credit_Mix']].values.ravel()
X_test = testing_data.drop(columns=['ID', 'Credit_Mix', 'Payment_of_Min_Amount'])
y_test = testing_data[['Credit_Mix']].values.ravel()
column_names = X_train.columns.tolist()

# %%
def plot_feature_importances(model):
    n_features = X_train.shape[1]
    plt.barh(np.arange(n_features), model.feature_importances_, align='center')
    plt.yticks(np.arange(n_features), column_names)
    plt.xlabel("Feature importance")
    plt.ylabel("Feature")
    plt.ylim(-1, n_features)

# %%
tree = DecisionTreeClassifier(random_state=0)
tree.fit(X_train, y_train)

print("Accuracy on training set: {:.3f}".format(tree.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(tree.score(X_test, y_test)))
# Out:
# Accuracy on training set: 1.000
# Accuracy on test set: 0.942

# %%
plot_feature_importances(tree)

# %%
forest = RandomForestClassifier(n_estimators=100, random_state=0)
forest.fit(X_train, y_train)

print("Accuracy on training set: {:.3f}".format(forest.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(forest.score(X_test, y_test)))
# Out:
# Accuracy on training set: 1.000
# Accuracy on test set: 0.967

# %%
plot_feature_importances(forest)

# %%
gbrt = GradientBoostingClassifier(random_state=0)
gbrt.fit(X_train, y_train)

print("Accuracy on training set: {:.3f}".format(gbrt.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(gbrt.score(X_test, y_test)))
# Out:
# Accuracy on training set: 0.936
# Accuracy on test set: 0.931

# %%
gbrt = GradientBoostingClassifier(random_state=0, max_depth=2,learning_rate=.44)
gbrt.fit(X_train, y_train)
print("Accuracy on training set: {:.3f}".format(gbrt.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(gbrt.score(X_test, y_test)))
plot_feature_importances(gbrt)
# Out:
# Accuracy on training set: 0.950
# Accuracy on test set: 0.941
